# %%
from sklearn.datasets import load_iris
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

# %%
# X, Y = load_iris(return_X_y=True)
iris = load_iris()
X = iris.data
Y = iris.target

target_names = iris.target_names
print(target_names)

X = X[:, :2]  # we only take the first two features.
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
model = svm.LinearSVC(max_iter=1000)
model.fit(X_train, y_train)
model.score(X_train, y_train)
# Out:
# C:\Users\Robotux\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 0.8083333333333333

# %%
model.score(X_test, y_test)
# Out:
# 0.8

# %%
from sklearn.metrics import ConfusionMatrixDisplay
y_pred = model.predict(X_test)
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, display_labels=target_names)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
y_pred_2 = model_2.predict(X_test)
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_2, display_labels=target_names)

# %%
model_2 = svm.SVC(max_iter=1000)
model_2.fit(X_train, y_train)
model_2.score(X_train, y_train)
# Out:
# 0.8166666666666667

# %%
model_2.score(X_test, y_test)
# Out:
# 0.8666666666666667

# %%
fig, axes = plt.subplots(1,2)

axes[0].scatter(X[:, 0], X[:, 1], c=Y)
axes[1].scatter(X[:, 0], X[:, 1], c=Y)

# For Plotting decision boundary
xlim = axes[0].get_xlim()
ylim = axes[0].get_ylim()
# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
print (model.predict(X_train).shape )
print (XX.shape)
print (xy.shape)
Z = model.predict(xy)
print (Z.shape)
Z = Z.reshape(XX.shape)
axes[0].contour(
    XX, YY, Z, colors="k", levels=[-1, 0, 1], alpha=0.5, linestyles=["--", "-", "--"]
)

Z_2 = model_2.predict(xy)
Z_2 = Z_2.reshape(XX.shape)
axes[1].contour(
    XX, YY, Z_2, colors="k", levels=[-1, 0, 1], alpha=0.5, linestyles=["--", "-", "--"]
)
# Out:
# (120,)
# (30, 30)
# (900, 2)
# (900,)

# %% [markdown]
# # K-NearestNeighbors

# %%
from sklearn.datasets import load_digits
from sklearn.neighbors import KNeighborsClassifier

digits = load_digits()

X = digits.data
Y = digits.target

# %%
print (X)
print (X.shape)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]
# (1797, 64)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
print (X_train.shape)
print (X_test.shape)
# Out:
# (1437, 64)
# (360, 64)

# %%
model = KNeighborsClassifier(n_neighbors=21)
model.fit(X_train, y_train)
model.score(X_train, y_train)
# Out:
# 0.9749478079331941

# %%
model.score(X_test, y_test)
# Out:
# 0.9722222222222222

# %%
from sklearn.metrics import ConfusionMatrixDisplay

target_names = digits.target_names
y_pred = model.predict(X_test)
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, display_labels=target_names)

# %% [markdown]
# # Decision trees

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

iris = load_iris()
X = iris.data
Y = iris.target
clf = DecisionTreeClassifier()

# %%
X.shape
# Out:
# (150, 4)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
model.score(X_train, y_train)
# Out:
# 1.0

# %%
model.score(X_test, y_test)
# Out:
# 0.9333333333333333

# %%
target_names = iris.target_names
y_pred = model.predict(X_test)
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, display_labels=target_names)

# %%
# For Plotting decision tree
plt.figure(dpi=400, figsize=(10,10) )
tree.plot_tree(model, feature_names=iris.feature_names, class_names=iris.target_names)
# Out:
# [Text(0.4, 0.9285714285714286, 'petal length (cm) <= 2.45\ngini = 0.666\nsamples = 120\nvalue = [43, 38, 39]\nclass = setosa'),
#  Text(0.3, 0.7857142857142857, 'gini = 0.0\nsamples = 43\nvalue = [43, 0, 0]\nclass = setosa'),
#  Text(0.5, 0.7857142857142857, 'petal length (cm) <= 4.75\ngini = 0.5\nsamples = 77\nvalue = [0, 38, 39]\nclass = virginica'),
#  Text(0.4, 0.6428571428571429, 'gini = 0.0\nsamples = 34\nvalue = [0, 34, 0]\nclass = versicolor'),
#  Text(0.6, 0.6428571428571429, 'petal width (cm) <= 1.75\ngini = 0.169\nsamples = 43\nvalue = [0, 4, 39]\nclass = virginica'),
#  Text(0.4, 0.5, 'petal length (cm) <= 5.35\ngini = 0.49\nsamples = 7\nvalue = [0, 3, 4]\nclass = virginica'),
#  Text(0.3, 0.35714285714285715, 'sepal length (cm) <= 6.5\ngini = 0.48\nsamples = 5\nvalue = [0, 3, 2]\nclass = versicolor'),
#  Text(0.2, 0.21428571428571427, 'petal width (cm) <= 1.55\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(0.1, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(0.3, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(0.4, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(0.5, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(0.8, 0.5, 'petal length (cm) <= 4.85\ngini = 0.054\nsamples = 36\nvalue = [0, 1, 35]\nclass = virginica'),
#  Text(0.7, 0.35714285714285715, 'sepal width (cm) <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(0.6, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(0.8, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(0.9, 0.35714285714285715, 'gini = 0.0\nsamples = 33\nvalue = [0, 0, 33]\nclass = virginica')]
